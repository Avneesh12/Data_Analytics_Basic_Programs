# %%
import seaborn as sns
import matplotlib as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Line Plot

# %%
tip_df = sns.load_dataset('tips')
tip_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(x='total_bill',y='tip',data=tip_df,marker='o')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x='tip',y='size',data=tip_df,marker='o',color='g')
# Out:
# <Axes: xlabel='tip', ylabel='size'>

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(tip_df.isnull())
# Out:
# <Axes: >

# %%
marks = pd.DataFrame({'py':[50,55,40,35],'ML':[70,80,40,60],'AI':[30,50,81,60]})

sns.heatmap(marks,annot=True,linewidths=2,linecolor='k')
# Out:
# <Axes: >

# %%
sns.heatmap(marks,annot=True,linewidths=2,linecolor='k',cmap='tab20')
# Out:
# <Axes: >

# %%
sns.heatmap(marks,annot=True,linewidths=2,linecolor='k',cmap='tab20',cbar=False,xticklabels=False,yticklabels=False)
# Out:
# <Axes: >

# %% [markdown]
# # Bar Plot

# %%
tip_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex',y='total_bill',data=tip_df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',data=tip_df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Histogram / Distplot

# %%
tip_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tip_df['total_bill'],hist_kws={'width':4,'color':'g'},kde_kws={'color':'r'})
# Out:
# C:\Users\Avniiii\AppData\Local\Temp\ipykernel_8372\2647302717.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tip_df['total_bill'],hist_kws={'width':4,'color':'g'},kde_kws={'color':'r'})
# <Axes: xlabel='total_bill', ylabel='Density'>
